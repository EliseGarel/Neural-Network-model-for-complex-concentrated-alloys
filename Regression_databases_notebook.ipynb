# %% [markdown]
# # Regression Neural Netwok on different databases

# %% [markdown]
# ## 1) Import libraries

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
from IPython.display import display, Markdown, clear_output
import fidle.pwk as ooo
from importlib import reload
import modele_fit as mf
from pathos.multiprocessing import ProcessingPool as Pool

# %% [markdown]
# ## 2) Parameters of the neural network

# %%
frac_train=0.8
shape=(5,) 
liste_entree=['Zr_at','Nb_at','Mo_at','Ti_at','Cr_at']
liste_sortie= [['E (GPa)','H (GPa)'],
               ['E (GPa)','H (GPa)'],
               ['E (GPa)','H (GPa)'],
               ['E (GPa)','H (GPa)'],
               ['E (GPa)','H (GPa)','stdE (GPa)','stdH (GPa)']]

nb_layers=2
list_neurones=[20,20]
neurones_sortie= [2,2,2,2,4]
list_act=['relu','relu']
f_opt='rmsprop'
crit_loss='mse'
list_metrics=['mse','mae']
nb_epochs=200
filename=['A:/BASE DE DONNEES/Nanoindentation/Python_extrac/Raw_data.csv',
          'A:/BASE DE DONNEES/Nanoindentation/Python_extrac/Raw_data_corrected.csv',
          'A:/BASE DE DONNEES/Nanoindentation/Python_extrac/Threshold_data_with_outliers.csv',
          'A:/BASE DE DONNEES/Nanoindentation/Python_extrac/Data_without_outliers.csv',
          'A:/BASE DE DONNEES/Nanoindentation/Python_extrac/Data_without_outliers_averaged.csv']

best_model_dir=['Raw_data',
                'Raw_data_corrected',
                'Threshold_data_with_outliers',
                'Data_without_outliers',
                'Data_without_outliers_averaged']
          
best_model_name=['best_Raw_data',
                'best_Raw_data_corrected',
                'best_Threshold_data_with_outliers',
                'best_Data_without_outliers',
                'best_Data_without_outliers_averaged']

# %% [markdown]
# ## 3) Run models

# %%
list_x_test=[]
list_y_test=[]
list_x_train=[]
list_y_train=[]
for i in range (0,5):
    x_test, y_test, x_train, y_train=mf.regression ([filename[i],
                                                     frac_train, 
                                                     shape, 
                                                     liste_entree, 
                                                     liste_sortie[i], 
                                                     nb_layers,
                                                     list_neurones,
                                                     neurones_sortie[i],
                                                     list_act,
                                                     f_opt,
                                                     crit_loss,
                                                     list_metrics, 
                                                     nb_epochs,
                                                     best_model_dir[i], 
                                                     best_model_name[i]])
    list_x_test.append(x_test)
    list_y_test.append(y_test)
    list_x_train.append(x_train)
    list_y_train.append(y_train)
# Out:
#   Unnamed: 0                   Indent  Zr_at  Nb_at  Mo_at  Ti_at  Cr_at  \
# 0     data_1  grad6-CrMo.xls indent 1    0.0   4.08  35.93   4.46  55.52
# 1     data_2  grad6-CrMo.xls indent 2    0.0   4.08  35.93   4.46  55.52
# 2     data_3  grad6-CrMo.xls indent 3    0.0   4.08  35.93   4.46  55.52
# 3     data_4  grad6-CrMo.xls indent 4    0.0   4.08  35.93   4.46  55.52
# 4     data_5  grad6-CrMo.xls indent 5    0.0   4.08  35.93   4.46  55.52
#
#    Zr_m  Nb_m   Mo_m  Ti_m   Cr_m     E (GPa)    H (GPa)
# 0   0.0  5.47  49.77  3.08  41.67  349.443381  14.178448
# 1   0.0  5.47  49.77  3.08  41.67  326.107154  13.016981
# 2   0.0  5.47  49.77  3.08  41.67  320.397024  12.776115
# 3   0.0  5.47  49.77  3.08  41.67  334.122897  13.240193
# 4   0.0  5.47  49.77  3.08  41.67  354.430235  13.878741
# Données manquantes :  0   Shape is :  (2265, 14)
# Original data shape was :  (2265, 14)
# x_train :  (1812, 5) y_train :  (1812, 2)
# x_test  :  (453, 5) y_test  :  (453, 2)
# <style  type="text/css" >
# </style><table id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69" ><caption>Before normalization :</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Zr_at</th>        <th class="col_heading level0 col1" >Nb_at</th>        <th class="col_heading level0 col2" >Mo_at</th>        <th class="col_heading level0 col3" >Ti_at</th>        <th class="col_heading level0 col4" >Cr_at</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row0_col0" class="data row0 col0" >1812.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row0_col1" class="data row0 col1" >1812.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row0_col2" class="data row0 col2" >1812.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row0_col3" class="data row0 col3" >1812.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row0_col4" class="data row0 col4" >1812.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row1_col0" class="data row1 col0" >14.46</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row1_col1" class="data row1 col1" >18.88</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row1_col2" class="data row1 col2" >22.21</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row1_col3" class="data row1 col3" >17.29</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row1_col4" class="data row1 col4" >27.16</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row2_col0" class="data row2 col0" >14.57</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row2_col1" class="data row2 col1" >19.54</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row2_col2" class="data row2 col2" >21.21</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row2_col3" class="data row2 col3" >17.82</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row2_col4" class="data row2 col4" >24.64</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row3_col2" class="data row3 col2" >0.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row3_col3" class="data row3 col3" >0.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row3_col4" class="data row3 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row4_col0" class="data row4 col0" >3.26</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row4_col1" class="data row4 col1" >4.16</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row4_col2" class="data row4 col2" >0.00</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row4_col3" class="data row4 col3" >0.80</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row4_col4" class="data row4 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row5_col0" class="data row5 col0" >10.97</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row5_col1" class="data row5 col1" >14.41</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row5_col2" class="data row5 col2" >18.49</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row5_col3" class="data row5 col3" >12.77</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row5_col4" class="data row5 col4" >24.27</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row6_col0" class="data row6 col0" >21.08</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row6_col1" class="data row6 col1" >26.38</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row6_col2" class="data row6 col2" >32.74</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row6_col3" class="data row6 col3" >25.78</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row6_col4" class="data row6 col4" >45.95</td>
#             </tr>
#             <tr>
#                         <th id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row7_col0" class="data row7 col0" >74.54</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row7_col1" class="data row7 col1" >87.24</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row7_col2" class="data row7 col2" >92.57</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row7_col3" class="data row7 col3" >76.46</td>
#                         <td id="T_e47310da_a1e4_11eb_b51e_6c2b59ed9a69row7_col4" class="data row7 col4" >92.70</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69" ><caption>After normalization :</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Zr_at</th>        <th class="col_heading level0 col1" >Nb_at</th>        <th class="col_heading level0 col2" >Mo_at</th>        <th class="col_heading level0 col3" >Ti_at</th>        <th class="col_heading level0 col4" >Cr_at</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row0_col0" class="data row0 col0" >1812.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row0_col1" class="data row0 col1" >1812.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row0_col2" class="data row0 col2" >1812.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row0_col3" class="data row0 col3" >1812.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row0_col4" class="data row0 col4" >1812.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row1_col0" class="data row1 col0" >-0.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row1_col1" class="data row1 col1" >-0.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row1_col2" class="data row1 col2" >-0.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row1_col3" class="data row1 col3" >0.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row1_col4" class="data row1 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row2_col0" class="data row2 col0" >1.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row2_col1" class="data row2 col1" >1.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row2_col4" class="data row2 col4" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row3_col0" class="data row3 col0" >-0.99</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row3_col1" class="data row3 col1" >-0.97</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row3_col2" class="data row3 col2" >-1.05</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row3_col3" class="data row3 col3" >-0.97</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row3_col4" class="data row3 col4" >-1.10</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row4_col0" class="data row4 col0" >-0.77</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row4_col1" class="data row4 col1" >-0.75</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row4_col2" class="data row4 col2" >-1.05</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row4_col3" class="data row4 col3" >-0.93</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row4_col4" class="data row4 col4" >-1.10</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row5_col0" class="data row5 col0" >-0.24</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row5_col1" class="data row5 col1" >-0.23</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row5_col2" class="data row5 col2" >-0.18</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row5_col3" class="data row5 col3" >-0.25</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row5_col4" class="data row5 col4" >-0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row6_col0" class="data row6 col0" >0.45</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row6_col1" class="data row6 col1" >0.38</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row6_col2" class="data row6 col2" >0.50</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row6_col3" class="data row6 col3" >0.48</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row6_col4" class="data row6 col4" >0.76</td>
#             </tr>
#             <tr>
#                         <th id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row7_col0" class="data row7 col0" >4.12</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row7_col1" class="data row7 col1" >3.50</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row7_col2" class="data row7 col2" >3.32</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row7_col3" class="data row7 col3" >3.32</td>
#                         <td id="T_e477561e_a1e4_11eb_af54_6c2b59ed9a69row7_col4" class="data row7 col4" >2.66</td>
#             </tr>
#     </tbody></table>
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 582
# Trainable params: 582
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 00001: val_loss improved from inf to 19077.46057, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00002: val_loss improved from 19077.46057 to 14355.11889, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00003: val_loss improved from 14355.11889 to 6845.59061, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00004: val_loss improved from 6845.59061 to 1360.09601, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00005: val_loss improved from 1360.09601 to 737.47351, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00006: val_loss improved from 737.47351 to 647.29389, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00007: val_loss improved from 647.29389 to 594.57512, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00008: val_loss improved from 594.57512 to 567.79362, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00009: val_loss improved from 567.79362 to 550.41475, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00010: val_loss improved from 550.41475 to 534.28104, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00011: val_loss improved from 534.28104 to 524.74197, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00012: val_loss improved from 524.74197 to 519.55848, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00013: val_loss improved from 519.55848 to 510.73513, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00014: val_loss improved from 510.73513 to 506.77813, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00015: val_loss improved from 506.77813 to 505.75634, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00016: val_loss did not improve from 505.75634
#
# Epoch 00017: val_loss improved from 505.75634 to 500.00655, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00018: val_loss did not improve from 500.00655
#
# Epoch 00019: val_loss improved from 500.00655 to 498.28220, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00020: val_loss improved from 498.28220 to 496.74569, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00021: val_loss improved from 496.74569 to 496.72195, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00022: val_loss improved from 496.72195 to 494.78803, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00023: val_loss improved from 494.78803 to 493.51672, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00024: val_loss improved from 493.51672 to 492.79198, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00025: val_loss did not improve from 492.79198
#
# Epoch 00026: val_loss did not improve from 492.79198
#
# Epoch 00027: val_loss improved from 492.79198 to 492.68919, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00028: val_loss improved from 492.68919 to 490.76264, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00029: val_loss improved from 490.76264 to 488.30930, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00030: val_loss did not improve from 488.30930
#
# Epoch 00031: val_loss improved from 488.30930 to 486.41768, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00032: val_loss did not improve from 486.41768
#
# Epoch 00033: val_loss did not improve from 486.41768
#
# Epoch 00034: val_loss did not improve from 486.41768
#
# Epoch 00035: val_loss did not improve from 486.41768
#
# Epoch 00036: val_loss improved from 486.41768 to 484.89784, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00037: val_loss improved from 484.89784 to 483.07589, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00038: val_loss improved from 483.07589 to 483.02965, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00039: val_loss improved from 483.02965 to 482.17794, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00040: val_loss improved from 482.17794 to 482.05167, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00041: val_loss improved from 482.05167 to 481.42731, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00042: val_loss improved from 481.42731 to 481.29322, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00043: val_loss improved from 481.29322 to 479.69828, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00044: val_loss did not improve from 479.69828
#
# Epoch 00045: val_loss improved from 479.69828 to 477.40444, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00046: val_loss did not improve from 477.40444
#
# Epoch 00047: val_loss improved from 477.40444 to 477.26957, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00048: val_loss did not improve from 477.26957
#
# Epoch 00049: val_loss did not improve from 477.26957
#
# Epoch 00050: val_loss improved from 477.26957 to 474.67826, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00051: val_loss improved from 474.67826 to 473.52599, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00052: val_loss improved from 473.52599 to 471.06077, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00053: val_loss did not improve from 471.06077
#
# Epoch 00054: val_loss did not improve from 471.06077
#
# Epoch 00055: val_loss did not improve from 471.06077
#
# Epoch 00056: val_loss did not improve from 471.06077
#
# Epoch 00057: val_loss improved from 471.06077 to 468.36925, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00058: val_loss improved from 468.36925 to 468.04940, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00059: val_loss did not improve from 468.04940
#
# Epoch 00060: val_loss did not improve from 468.04940
#
# Epoch 00061: val_loss did not improve from 468.04940
#
# Epoch 00062: val_loss improved from 468.04940 to 466.96854, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00063: val_loss improved from 466.96854 to 466.44048, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00064: val_loss did not improve from 466.44048
#
# Epoch 00065: val_loss did not improve from 466.44048
#
# Epoch 00066: val_loss did not improve from 466.44048
#
# Epoch 00067: val_loss did not improve from 466.44048
#
# Epoch 00068: val_loss improved from 466.44048 to 463.36290, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00069: val_loss did not improve from 463.36290
#
# Epoch 00070: val_loss improved from 463.36290 to 462.44421, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00071: val_loss improved from 462.44421 to 461.03503, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00072: val_loss improved from 461.03503 to 458.53787, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00073: val_loss did not improve from 458.53787
#
# Epoch 00074: val_loss improved from 458.53787 to 456.75308, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00075: val_loss did not improve from 456.75308
#
# Epoch 00076: val_loss did not improve from 456.75308
#
# Epoch 00077: val_loss did not improve from 456.75308
#
# Epoch 00078: val_loss did not improve from 456.75308
#
# Epoch 00079: val_loss did not improve from 456.75308
#
# Epoch 00080: val_loss did not improve from 456.75308
#
# Epoch 00081: val_loss improved from 456.75308 to 456.34089, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00082: val_loss did not improve from 456.34089
#
# Epoch 00083: val_loss did not improve from 456.34089
#
# Epoch 00084: val_loss did not improve from 456.34089
#
# Epoch 00085: val_loss improved from 456.34089 to 456.28392, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00086: val_loss improved from 456.28392 to 454.90410, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00087: val_loss improved from 454.90410 to 452.93087, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00088: val_loss did not improve from 452.93087
#
# Epoch 00089: val_loss improved from 452.93087 to 452.48130, saving model to ./Raw_data/best_Raw_data.h5
# Epoch 00090: val_loss did not improve from 452.48130
#
# Epoch 00091: val_loss improved from 452.48130 to 451.02441, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00092: val_loss did not improve from 451.02441
#
# Epoch 00093: val_loss did not improve from 451.02441
#
# Epoch 00094: val_loss improved from 451.02441 to 450.12272, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00095: val_loss improved from 450.12272 to 449.27186, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00096: val_loss did not improve from 449.27186
#
# Epoch 00097: val_loss did not improve from 449.27186
#
# Epoch 00098: val_loss improved from 449.27186 to 449.24765, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00099: val_loss did not improve from 449.24765
#
# Epoch 00100: val_loss did not improve from 449.24765
#
# Epoch 00101: val_loss did not improve from 449.24765
#
# Epoch 00102: val_loss did not improve from 449.24765
#
# Epoch 00103: val_loss did not improve from 449.24765
#
# Epoch 00104: val_loss did not improve from 449.24765
#
# Epoch 00105: val_loss did not improve from 449.24765
#
# Epoch 00106: val_loss did not improve from 449.24765
#
# Epoch 00107: val_loss improved from 449.24765 to 448.20270, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00108: val_loss did not improve from 448.20270
#
# Epoch 00109: val_loss did not improve from 448.20270
#
# Epoch 00110: val_loss improved from 448.20270 to 447.62732, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00111: val_loss did not improve from 447.62732
#
# Epoch 00112: val_loss did not improve from 447.62732
#
# Epoch 00113: val_loss improved from 447.62732 to 446.76723, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00114: val_loss did not improve from 446.76723
#
# Epoch 00115: val_loss improved from 446.76723 to 446.75069, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00116: val_loss did not improve from 446.75069
#
# Epoch 00117: val_loss did not improve from 446.75069
#
# Epoch 00118: val_loss did not improve from 446.75069
#
# Epoch 00119: val_loss improved from 446.75069 to 445.95667, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00120: val_loss did not improve from 445.95667
#
# Epoch 00121: val_loss did not improve from 445.95667
#
# Epoch 00122: val_loss did not improve from 445.95667
#
# Epoch 00123: val_loss improved from 445.95667 to 444.10277, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00124: val_loss improved from 444.10277 to 443.37106, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00125: val_loss did not improve from 443.37106
#
# Epoch 00126: val_loss did not improve from 443.37106
#
# Epoch 00127: val_loss did not improve from 443.37106
#
# Epoch 00128: val_loss did not improve from 443.37106
#
# Epoch 00129: val_loss did not improve from 443.37106
#
# Epoch 00130: val_loss did not improve from 443.37106
#
# Epoch 00131: val_loss improved from 443.37106 to 442.55276, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00132: val_loss did not improve from 442.55276
#
# Epoch 00133: val_loss improved from 442.55276 to 442.13418, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00134: val_loss did not improve from 442.13418
#
# Epoch 00135: val_loss did not improve from 442.13418
#
# Epoch 00136: val_loss did not improve from 442.13418
#
# Epoch 00137: val_loss improved from 442.13418 to 441.97029, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00138: val_loss did not improve from 441.97029
#
# Epoch 00139: val_loss did not improve from 441.97029
#
# Epoch 00140: val_loss improved from 441.97029 to 441.95909, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00141: val_loss did not improve from 441.95909
#
# Epoch 00142: val_loss improved from 441.95909 to 441.80996, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00143: val_loss did not improve from 441.80996
#
# Epoch 00144: val_loss did not improve from 441.80996
#
# Epoch 00145: val_loss did not improve from 441.80996
#
# Epoch 00146: val_loss did not improve from 441.80996
#
# Epoch 00147: val_loss did not improve from 441.80996
#
# Epoch 00148: val_loss improved from 441.80996 to 441.47874, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00149: val_loss did not improve from 441.47874
#
# Epoch 00150: val_loss did not improve from 441.47874
#
# Epoch 00151: val_loss improved from 441.47874 to 439.98604, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00152: val_loss did not improve from 439.98604
#
# Epoch 00153: val_loss did not improve from 439.98604
#
# Epoch 00154: val_loss did not improve from 439.98604
#
# Epoch 00155: val_loss did not improve from 439.98604
#
# Epoch 00156: val_loss did not improve from 439.98604
#
# Epoch 00157: val_loss did not improve from 439.98604
#
# Epoch 00158: val_loss did not improve from 439.98604
#
# Epoch 00159: val_loss did not improve from 439.98604
#
# Epoch 00160: val_loss did not improve from 439.98604
#
# Epoch 00161: val_loss improved from 439.98604 to 439.15922, saving model to ./Raw_data/best_Raw_data.h5
#
# Epoch 00162: val_loss did not improve from 439.15922
#
# Epoch 00163: val_loss did not improve from 439.15922
#
# Epoch 00164: val_loss did not improve from 439.15922
#
# Epoch 00165: val_loss did not improve from 439.15922
#
# Epoch 00166: val_loss did not improve from 439.15922
#
# Epoch 00167: val_loss did not improve from 439.15922
#
# Epoch 00168: val_loss did not improve from 439.15922
#
# Epoch 00169: val_loss did not improve from 439.15922
#
# Epoch 00170: val_loss did not improve from 439.15922
#
# Epoch 00171: val_loss did not improve from 439.15922
#
# Epoch 00172: val_loss did not improve from 439.15922
#
# Epoch 00173: val_loss did not improve from 439.15922
#
# Epoch 00174: val_loss did not improve from 439.15922
#
# Epoch 00175: val_loss did not improve from 439.15922
#
# Epoch 00176: val_loss did not improve from 439.15922
#
# Epoch 00177: val_loss did not improve from 439.15922
#
# Epoch 00178: val_loss did not improve from 439.15922
#
# Epoch 00179: val_loss did not improve from 439.15922
#
# Epoch 00180: val_loss did not improve from 439.15922
#
# Epoch 00181: val_loss did not improve from 439.15922
#
# Epoch 00182: val_loss did not improve from 439.15922
#
# Epoch 00183: val_loss did not improve from 439.15922
#
# Epoch 00184: val_loss did not improve from 439.15922
#
# Epoch 00185: val_loss did not improve from 439.15922
#
# Epoch 00186: val_loss did not improve from 439.15922
#
# Epoch 00187: val_loss did not improve from 439.15922
#
# Epoch 00188: val_loss did not improve from 439.15922
#
# Epoch 00189: val_loss did not improve from 439.15922
#
# Epoch 00190: val_loss did not improve from 439.15922
#
# Epoch 00191: val_loss did not improve from 439.15922
#
# Epoch 00192: val_loss did not improve from 439.15922
#
# Epoch 00193: val_loss did not improve from 439.15922
#
# Epoch 00194: val_loss did not improve from 439.15922
#
# Epoch 00195: val_loss did not improve from 439.15922
#
# Epoch 00196: val_loss did not improve from 439.15922
#
# Epoch 00197: val_loss did not improve from 439.15922
#
# Epoch 00198: val_loss did not improve from 439.15922
#
# Epoch 00199: val_loss did not improve from 439.15922
#
# Epoch 00200: val_loss did not improve from 439.15922
#   Unnamed: 0                   Indent  Zr_at  Nb_at  Mo_at  Ti_at  Cr_at  \
# 0     data_1  grad6-CrMo.xls indent 1    0.0   4.08  35.93   4.46  55.52
# 1     data_2  grad6-CrMo.xls indent 2    0.0   4.08  35.93   4.46  55.52
# 2     data_3  grad6-CrMo.xls indent 3    0.0   4.08  35.93   4.46  55.52
# 3     data_4  grad6-CrMo.xls indent 4    0.0   4.08  35.93   4.46  55.52
# 4     data_5  grad6-CrMo.xls indent 5    0.0   4.08  35.93   4.46  55.52
#
#    Zr_m  Nb_m   Mo_m  Ti_m   Cr_m     E (GPa)    H (GPa)
# 0   0.0  5.47  49.77  3.08  41.67  343.515155  13.957295
# 1   0.0  5.47  49.77  3.08  41.67  325.932726  12.694453
# 2   0.0  5.47  49.77  3.08  41.67  327.826397  12.823438
# 3   0.0  5.47  49.77  3.08  41.67  333.495190  13.348976
# 4   0.0  5.47  49.77  3.08  41.67  353.433284  14.131835
# Données manquantes :  0   Shape is :  (2265, 14)
# Original data shape was :  (2265, 14)
# x_train :  (1812, 5) y_train :  (1812, 2)
# x_test  :  (453, 5) y_test  :  (453, 2)
# <style  type="text/css" >
# </style><table id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69" ><caption>Before normalization :</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Zr_at</th>        <th class="col_heading level0 col1" >Nb_at</th>        <th class="col_heading level0 col2" >Mo_at</th>        <th class="col_heading level0 col3" >Ti_at</th>        <th class="col_heading level0 col4" >Cr_at</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row0_col0" class="data row0 col0" >1812.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row0_col1" class="data row0 col1" >1812.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row0_col2" class="data row0 col2" >1812.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row0_col3" class="data row0 col3" >1812.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row0_col4" class="data row0 col4" >1812.00</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row1_col0" class="data row1 col0" >14.28</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row1_col1" class="data row1 col1" >18.45</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row1_col2" class="data row1 col2" >22.41</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row1_col3" class="data row1 col3" >17.46</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row1_col4" class="data row1 col4" >27.40</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row2_col0" class="data row2 col0" >14.36</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row2_col1" class="data row2 col1" >19.21</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row2_col2" class="data row2 col2" >21.27</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row2_col3" class="data row2 col3" >17.89</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row2_col4" class="data row2 col4" >24.67</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row3_col1" class="data row3 col1" >0.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row3_col2" class="data row3 col2" >0.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row3_col3" class="data row3 col3" >0.00</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row3_col4" class="data row3 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row4_col0" class="data row4 col0" >3.28</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row4_col1" class="data row4 col1" >4.16</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row4_col2" class="data row4 col2" >2.07</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row4_col3" class="data row4 col3" >0.76</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row4_col4" class="data row4 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row5_col0" class="data row5 col0" >10.79</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row5_col1" class="data row5 col1" >13.99</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row5_col2" class="data row5 col2" >18.59</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row5_col3" class="data row5 col3" >13.02</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row5_col4" class="data row5 col4" >24.25</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row6_col0" class="data row6 col0" >21.08</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row6_col1" class="data row6 col1" >25.53</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row6_col2" class="data row6 col2" >32.74</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row6_col3" class="data row6 col3" >26.50</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row6_col4" class="data row6 col4" >45.96</td>
#             </tr>
#             <tr>
#                         <th id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row7_col0" class="data row7 col0" >74.54</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row7_col1" class="data row7 col1" >87.24</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row7_col2" class="data row7 col2" >92.57</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row7_col3" class="data row7 col3" >76.46</td>
#                         <td id="T_2879f692_a1e5_11eb_af62_6c2b59ed9a69row7_col4" class="data row7 col4" >92.70</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69" ><caption>After normalization :</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Zr_at</th>        <th class="col_heading level0 col1" >Nb_at</th>        <th class="col_heading level0 col2" >Mo_at</th>        <th class="col_heading level0 col3" >Ti_at</th>        <th class="col_heading level0 col4" >Cr_at</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row0_col0" class="data row0 col0" >1812.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row0_col1" class="data row0 col1" >1812.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row0_col2" class="data row0 col2" >1812.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row0_col3" class="data row0 col3" >1812.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row0_col4" class="data row0 col4" >1812.00</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row1_col0" class="data row1 col0" >-0.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row1_col1" class="data row1 col1" >-0.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row1_col2" class="data row1 col2" >-0.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row1_col3" class="data row1 col3" >0.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row1_col4" class="data row1 col4" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row2_col0" class="data row2 col0" >1.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row2_col1" class="data row2 col1" >1.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row2_col3" class="data row2 col3" >1.00</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row2_col4" class="data row2 col4" >1.00</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row3_col0" class="data row3 col0" >-0.99</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row3_col1" class="data row3 col1" >-0.96</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row3_col2" class="data row3 col2" >-1.05</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row3_col3" class="data row3 col3" >-0.98</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row3_col4" class="data row3 col4" >-1.11</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row4_col0" class="data row4 col0" >-0.77</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row4_col1" class="data row4 col1" >-0.74</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row4_col2" class="data row4 col2" >-0.96</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row4_col3" class="data row4 col3" >-0.93</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row4_col4" class="data row4 col4" >-1.11</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row5_col0" class="data row5 col0" >-0.24</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row5_col1" class="data row5 col1" >-0.23</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row5_col2" class="data row5 col2" >-0.18</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row5_col3" class="data row5 col3" >-0.25</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row5_col4" class="data row5 col4" >-0.13</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row6_col0" class="data row6 col0" >0.47</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row6_col1" class="data row6 col1" >0.37</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row6_col2" class="data row6 col2" >0.49</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row6_col3" class="data row6 col3" >0.51</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row6_col4" class="data row6 col4" >0.75</td>
#             </tr>
#             <tr>
#                         <th id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69level0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row7_col0" class="data row7 col0" >4.20</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row7_col1" class="data row7 col1" >3.58</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row7_col2" class="data row7 col2" >3.30</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row7_col3" class="data row7 col3" >3.30</td>
#                         <td id="T_2880106e_a1e5_11eb_a651_6c2b59ed9a69row7_col4" class="data row7 col4" >2.65</td>
#             </tr>
#     </tbody></table>
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 582
# Trainable params: 582
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 00001: val_loss improved from inf to 18484.32524, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00002: val_loss improved from 18484.32524 to 12309.49727, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00003: val_loss improved from 12309.49727 to 4099.08843, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00004: val_loss improved from 4099.08843 to 708.42190, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00005: val_loss improved from 708.42190 to 543.55014, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00006: val_loss improved from 543.55014 to 501.76079, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00007: val_loss improved from 501.76079 to 463.65582, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00008: val_loss improved from 463.65582 to 445.54569, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00009: val_loss improved from 445.54569 to 422.59067, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00010: val_loss improved from 422.59067 to 411.46915, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00011: val_loss improved from 411.46915 to 401.68850, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00012: val_loss improved from 401.68850 to 395.18480, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00013: val_loss did not improve from 395.18480
#
# Epoch 00014: val_loss improved from 395.18480 to 387.86094, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00015: val_loss improved from 387.86094 to 382.65432, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00016: val_loss improved from 382.65432 to 380.36841, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00017: val_loss did not improve from 380.36841
#
# Epoch 00018: val_loss improved from 380.36841 to 375.49269, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00019: val_loss improved from 375.49269 to 375.02436, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00020: val_loss did not improve from 375.02436
#
# Epoch 00021: val_loss improved from 375.02436 to 366.52967, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00022: val_loss did not improve from 366.52967
#
# Epoch 00023: val_loss improved from 366.52967 to 364.61149, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00024: val_loss improved from 364.61149 to 364.05988, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00025: val_loss improved from 364.05988 to 359.13526, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00026: val_loss did not improve from 359.13526
#
# Epoch 00027: val_loss did not improve from 359.13526
#
# Epoch 00028: val_loss did not improve from 359.13526
#
# Epoch 00029: val_loss did not improve from 359.13526
#
# Epoch 00030: val_loss did not improve from 359.13526
#
# Epoch 00031: val_loss improved from 359.13526 to 352.30595, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00032: val_loss did not improve from 352.30595
#
# Epoch 00033: val_loss did not improve from 352.30595
#
# Epoch 00034: val_loss improved from 352.30595 to 351.42086, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00035: val_loss did not improve from 351.42086
#
# Epoch 00036: val_loss improved from 351.42086 to 348.38626, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00037: val_loss did not improve from 348.38626
#
# Epoch 00038: val_loss did not improve from 348.38626
#
# Epoch 00039: val_loss improved from 348.38626 to 346.29859, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# Epoch 00040: val_loss did not improve from 346.29859
#
# Epoch 00041: val_loss did not improve from 346.29859
#
# Epoch 00042: val_loss did not improve from 346.29859
#
# Epoch 00043: val_loss did not improve from 346.29859
#
# Epoch 00044: val_loss did not improve from 346.29859
#
# Epoch 00045: val_loss improved from 346.29859 to 342.81761, saving model to ./Raw_data_corrected/best_Raw_data_corrected.h5
#
# ...
#
# Epoch 00016: val_loss improved from 1630.59831 to 1017.09959, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00017: val_loss improved from 1017.09959 to 615.46554, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00018: val_loss improved from 615.46554 to 409.76823, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00019: val_loss improved from 409.76823 to 354.90371, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00020: val_loss improved from 354.90371 to 318.62391, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00021: val_loss improved from 318.62391 to 295.49759, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00022: val_loss improved from 295.49759 to 266.87255, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00023: val_loss improved from 266.87255 to 246.90603, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00024: val_loss improved from 246.90603 to 237.96096, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00025: val_loss improved from 237.96096 to 220.80555, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00026: val_loss improved from 220.80555 to 204.18610, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00027: val_loss improved from 204.18610 to 190.19291, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00028: val_loss improved from 190.19291 to 181.61957, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00029: val_loss improved from 181.61957 to 180.02288, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00030: val_loss improved from 180.02288 to 175.62434, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00031: val_loss improved from 175.62434 to 162.22129, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00032: val_loss improved from 162.22129 to 156.33088, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00033: val_loss improved from 156.33088 to 149.95756, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00034: val_loss improved from 149.95756 to 144.38194, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00035: val_loss did not improve from 144.38194
#
# Epoch 00036: val_loss improved from 144.38194 to 137.19574, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00037: val_loss did not improve from 137.19574
#
# Epoch 00038: val_loss improved from 137.19574 to 129.55736, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00039: val_loss did not improve from 129.55736
#
# Epoch 00040: val_loss improved from 129.55736 to 124.60445, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00041: val_loss did not improve from 124.60445
#
# Epoch 00042: val_loss improved from 124.60445 to 123.93572, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00043: val_loss improved from 123.93572 to 123.01895, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00044: val_loss did not improve from 123.01895
#
# Epoch 00045: val_loss improved from 123.01895 to 117.88203, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00046: val_loss did not improve from 117.88203
#
# Epoch 00047: val_loss improved from 117.88203 to 117.74028, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00048: val_loss improved from 117.74028 to 116.96770, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00049: val_loss did not improve from 116.96770
#
# Epoch 00050: val_loss improved from 116.96770 to 112.69968, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00051: val_loss did not improve from 112.69968
#
# Epoch 00052: val_loss did not improve from 112.69968
#
# Epoch 00053: val_loss did not improve from 112.69968
#
# Epoch 00054: val_loss did not improve from 112.69968
#
# Epoch 00055: val_loss improved from 112.69968 to 111.06983, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00056: val_loss improved from 111.06983 to 106.38323, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00057: val_loss did not improve from 106.38323
#
# Epoch 00058: val_loss did not improve from 106.38323
#
# Epoch 00059: val_loss improved from 106.38323 to 105.75011, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
# Epoch 00060: val_loss did not improve from 105.75011
#
# Epoch 00061: val_loss did not improve from 105.75011
#
# Epoch 00062: val_loss did not improve from 105.75011
#
# Epoch 00063: val_loss did not improve from 105.75011
#
# Epoch 00064: val_loss did not improve from 105.75011
#
# Epoch 00065: val_loss improved from 105.75011 to 105.38232, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00066: val_loss improved from 105.38232 to 104.55776, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00067: val_loss did not improve from 104.55776
#
# Epoch 00068: val_loss did not improve from 104.55776
#
# Epoch 00069: val_loss did not improve from 104.55776
#
# Epoch 00070: val_loss improved from 104.55776 to 104.18679, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00071: val_loss did not improve from 104.18679
#
# Epoch 00072: val_loss improved from 104.18679 to 104.12253, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00073: val_loss improved from 104.12253 to 101.64682, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00074: val_loss improved from 101.64682 to 100.64325, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00075: val_loss did not improve from 100.64325
#
# Epoch 00076: val_loss improved from 100.64325 to 99.27818, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00077: val_loss did not improve from 99.27818
#
# Epoch 00078: val_loss improved from 99.27818 to 98.23097, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00079: val_loss did not improve from 98.23097
#
# Epoch 00080: val_loss did not improve from 98.23097
#
# Epoch 00081: val_loss did not improve from 98.23097
#
# Epoch 00082: val_loss did not improve from 98.23097
#
# Epoch 00083: val_loss did not improve from 98.23097
#
# Epoch 00084: val_loss did not improve from 98.23097
#
# Epoch 00085: val_loss did not improve from 98.23097
#
# Epoch 00086: val_loss did not improve from 98.23097
#
# Epoch 00087: val_loss improved from 98.23097 to 97.54614, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00088: val_loss did not improve from 97.54614
#
# Epoch 00089: val_loss did not improve from 97.54614
#
# Epoch 00090: val_loss did not improve from 97.54614
#
# Epoch 00091: val_loss did not improve from 97.54614
#
# Epoch 00092: val_loss did not improve from 97.54614
#
# Epoch 00093: val_loss did not improve from 97.54614
#
# Epoch 00094: val_loss did not improve from 97.54614
#
# Epoch 00095: val_loss improved from 97.54614 to 95.82391, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00096: val_loss improved from 95.82391 to 93.89487, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00097: val_loss did not improve from 93.89487
#
# Epoch 00098: val_loss did not improve from 93.89487
#
# Epoch 00099: val_loss improved from 93.89487 to 92.79137, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00100: val_loss did not improve from 92.79137
#
# Epoch 00101: val_loss improved from 92.79137 to 92.40437, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00102: val_loss did not improve from 92.40437
#
# Epoch 00103: val_loss did not improve from 92.40437
#
# Epoch 00104: val_loss did not improve from 92.40437
#
# Epoch 00105: val_loss did not improve from 92.40437
#
# Epoch 00106: val_loss did not improve from 92.40437
#
# Epoch 00107: val_loss did not improve from 92.40437
#
# Epoch 00108: val_loss improved from 92.40437 to 91.72779, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00109: val_loss did not improve from 91.72779
#
# Epoch 00110: val_loss did not improve from 91.72779
#
# Epoch 00111: val_loss did not improve from 91.72779
#
# Epoch 00112: val_loss did not improve from 91.72779
#
# Epoch 00113: val_loss did not improve from 91.72779
#
# Epoch 00114: val_loss did not improve from 91.72779
#
# Epoch 00115: val_loss did not improve from 91.72779
#
# Epoch 00116: val_loss did not improve from 91.72779
#
# Epoch 00117: val_loss improved from 91.72779 to 91.65094, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00118: val_loss did not improve from 91.65094
#
# Epoch 00119: val_loss did not improve from 91.65094
#
# Epoch 00120: val_loss did not improve from 91.65094
#
# Epoch 00121: val_loss did not improve from 91.65094
#
# Epoch 00122: val_loss improved from 91.65094 to 88.65143, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00123: val_loss did not improve from 88.65143
#
# Epoch 00124: val_loss improved from 88.65143 to 88.00691, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00125: val_loss did not improve from 88.00691
#
# Epoch 00126: val_loss did not improve from 88.00691
#
# Epoch 00127: val_loss did not improve from 88.00691
#
# Epoch 00128: val_loss did not improve from 88.00691
#
# Epoch 00129: val_loss did not improve from 88.00691
#
# Epoch 00130: val_loss did not improve from 88.00691
#
# Epoch 00131: val_loss improved from 88.00691 to 86.93317, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00132: val_loss did not improve from 86.93317
#
# Epoch 00133: val_loss did not improve from 86.93317
#
# Epoch 00134: val_loss did not improve from 86.93317
#
# Epoch 00135: val_loss did not improve from 86.93317
#
# Epoch 00136: val_loss did not improve from 86.93317
#
# Epoch 00137: val_loss did not improve from 86.93317
#
# Epoch 00138: val_loss did not improve from 86.93317
#
# Epoch 00139: val_loss did not improve from 86.93317
#
# Epoch 00140: val_loss did not improve from 86.93317
#
# Epoch 00141: val_loss did not improve from 86.93317
#
# Epoch 00142: val_loss improved from 86.93317 to 84.68747, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00143: val_loss did not improve from 84.68747
#
# Epoch 00144: val_loss did not improve from 84.68747
#
# Epoch 00145: val_loss did not improve from 84.68747
#
# Epoch 00146: val_loss did not improve from 84.68747
#
# Epoch 00147: val_loss improved from 84.68747 to 84.36032, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00148: val_loss did not improve from 84.36032
#
# Epoch 00149: val_loss improved from 84.36032 to 83.05063, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00150: val_loss did not improve from 83.05063
#
# Epoch 00151: val_loss did not improve from 83.05063
#
# Epoch 00152: val_loss did not improve from 83.05063
#
# Epoch 00153: val_loss did not improve from 83.05063
#
# Epoch 00154: val_loss did not improve from 83.05063
#
# Epoch 00155: val_loss did not improve from 83.05063
#
# Epoch 00156: val_loss did not improve from 83.05063
#
# Epoch 00157: val_loss improved from 83.05063 to 82.66267, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00158: val_loss improved from 82.66267 to 80.21914, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00159: val_loss did not improve from 80.21914
#
# Epoch 00160: val_loss improved from 80.21914 to 79.22539, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00161: val_loss did not improve from 79.22539
#
# Epoch 00162: val_loss did not improve from 79.22539
#
# Epoch 00163: val_loss did not improve from 79.22539
#
# Epoch 00164: val_loss did not improve from 79.22539
#
# Epoch 00165: val_loss did not improve from 79.22539
#
# Epoch 00166: val_loss improved from 79.22539 to 77.11578, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00167: val_loss did not improve from 77.11578
#
# Epoch 00168: val_loss did not improve from 77.11578
#
# Epoch 00169: val_loss did not improve from 77.11578
#
# Epoch 00170: val_loss did not improve from 77.11578
# Epoch 00171: val_loss did not improve from 77.11578
#
# Epoch 00172: val_loss did not improve from 77.11578
#
# Epoch 00173: val_loss did not improve from 77.11578
#
# Epoch 00174: val_loss did not improve from 77.11578
#
# Epoch 00175: val_loss improved from 77.11578 to 74.18170, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00176: val_loss improved from 74.18170 to 73.15222, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00177: val_loss improved from 73.15222 to 72.89160, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00178: val_loss did not improve from 72.89160
#
# Epoch 00179: val_loss did not improve from 72.89160
#
# Epoch 00180: val_loss did not improve from 72.89160
#
# Epoch 00181: val_loss did not improve from 72.89160
#
# Epoch 00182: val_loss did not improve from 72.89160
#
# Epoch 00183: val_loss improved from 72.89160 to 71.66485, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00184: val_loss did not improve from 71.66485
#
# Epoch 00185: val_loss did not improve from 71.66485
#
# Epoch 00186: val_loss did not improve from 71.66485
#
# Epoch 00187: val_loss did not improve from 71.66485
#
# Epoch 00188: val_loss did not improve from 71.66485
#
# Epoch 00189: val_loss did not improve from 71.66485
#
# Epoch 00190: val_loss improved from 71.66485 to 70.95538, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00191: val_loss did not improve from 70.95538
#
# Epoch 00192: val_loss improved from 70.95538 to 69.32253, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00193: val_loss did not improve from 69.32253
#
# Epoch 00194: val_loss did not improve from 69.32253
#
# Epoch 00195: val_loss did not improve from 69.32253
#
# Epoch 00196: val_loss did not improve from 69.32253
#
# Epoch 00197: val_loss did not improve from 69.32253
#
# Epoch 00198: val_loss improved from 69.32253 to 68.47272, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5
#
# Epoch 00199: val_loss did not improve from 68.47272
#
# Epoch 00200: val_loss improved from 68.47272 to 67.31978, saving model to ./Data_without_outliers_averaged/best_Data_without_outliers_averaged.h5

# %% [markdown]
# ## 4) Evaluate best models

# %%
loaded_model=[]
score=[]
for i in range (0,5):
    loaded_model.append(keras.models.load_model('./'+best_model_dir[i]+'/'+best_model_name[i]+'.h5'))
    loaded_model[i].summary()
    print("Loaded.")
    score = loaded_model[i].evaluate(list_x_test[i], list_y_test[i], verbose=0)
    print('Test loss      : {:5.4f}'.format(score[0]))
    print('Test mse  : {:5.4f}'.format(score[1]))
    print('Test mae  : {:5.4f}'.format(score[2]))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 582
# Trainable params: 582
# Non-trainable params: 0
# _________________________________________________________________
# Loaded.
# Test loss      : 439.1592
# Test mae  : 439.1592
# Test mse  : 439.1592
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_19 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_20 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 582
# Trainable params: 582
# Non-trainable params: 0
# _________________________________________________________________
# Loaded.
# Test loss      : 315.0969
# Test mae  : 315.0969
# Test mse  : 315.0969
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_22 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_23 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 582
# Trainable params: 582
# Non-trainable params: 0
# _________________________________________________________________
# Loaded.
# Test loss      : 152.8746
# Test mae  : 152.8746
# Test mse  : 152.8746
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_24 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_25 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 42
# =================================================================
# Total params: 582
# Trainable params: 582
# Non-trainable params: 0
# _________________________________________________________________
# Loaded.
# Test loss      : 107.2640
# Test mae  : 107.2640
# Test mse  : 107.2640
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 20)                120
# _________________________________________________________________
# dense_28 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_29 (Dense)             (None, 4)                 84
# =================================================================
# Total params: 624
# Trainable params: 624
# Non-trainable params: 0
# _________________________________________________________________
# Loaded.
# Test loss      : 67.3198
# Test mae  : 67.3198
# Test mse  : 67.3198

# %% [markdown]
# ## 5) Plot predictions vs experimental for all databases + residual historgram

# %%
for i in range (0,5):

    predictions_test = loaded_model[i].predict(list_x_test[i])
    predictions_train = loaded_model[i].predict(list_x_train[i])
    y_train=list_y_train[i]
    y_test=list_y_test[i]
   
    for j in range (0,len(y_train[1,:])):
        res_train=(predictions_train[:,j]- y_train[:,j])
        res_test=(predictions_test[:,j]- y_test[:,j])
        
        plt.plot(predictions_train[:,j],y_train[:,j],'+')
        plt.title(best_model_dir[i]+': ' + liste_sortie[i][j]+" prediction vs "+liste_sortie[i][j]+" experimental on training data")
        plt.savefig('./'+best_model_dir[i]+'/'+liste_sortie[i][j]+'_train')
        plt.show()
        
        plt.plot(predictions_test[:,j],y_test[:,j],'+')
        plt.title(best_model_dir[i]+':  '+liste_sortie[i][j]+" prediction vs "+liste_sortie[i][j]+" experimental on testing data")
        plt.savefig('./'+best_model_dir[i]+'/'+liste_sortie[i][j]+'_test')
        plt.show()
        
        plt.hist(res_train) 
        plt.title(best_model_dir[i]+': residus of '+liste_sortie[i][j] +' for train')
        plt.savefig('./'+best_model_dir[i]+'/'+'Residus '+liste_sortie[i][j]+'_train')
        plt.show()
        
        plt.hist(res_test)
        plt.title(best_model_dir[i]+': residus of '+liste_sortie[i][j] +' for test')
        plt.savefig('./'+best_model_dir[i]+'/''Residus '+liste_sortie[i][j]+'_test')
        plt.show()
